# %% [markdown]
# # Downloading NASDAQ data using Yahoo! Finance.

# %%
# incase yahoo finance is not installed...
# !pip install --upgrade --no-cache-dir yfinance

# %%
import pandas as pd
import yfinance as yf
import os, contextlib
import shutil
from os.path import isfile, join

import os
import logging
import pandas as pd
import yfinance as yf
import requests
from io import StringIO
from concurrent.futures import ThreadPoolExecutor, as_completed
from requests.adapters import HTTPAdapter

# %%
# Set up a global session with increased connection pool size
global_session = requests.Session()
adapter = HTTPAdapter(pool_connections=100, pool_maxsize=100)
global_session.mount("http://", adapter)
global_session.mount("https://", adapter)

# %%
# Disable InsecureRequestWarning (only for testing purposes)
requests.packages.urllib3.disable_warnings(requests.packages.urllib3.exceptions.InsecureRequestWarning)

# %%
# Configure logging to log errors to "errors.log"
logging.basicConfig(filename="errors.log", level=logging.WARNING,
                    format='%(asctime)s - %(levelname)s - %(message)s')

# %%
def get_nasdaq_symbols(data_dir):
    """
    Download the list of NASDAQ traded symbols from the NASDAQ Trader website.
    The file is pipe-separated and contains footer rows and test issues.
    Filters out rows where 'Test Issue' is not 'N', saves the full
    reference DataFrame to the provided directory, and returns the list of symbols.
    """
    url = "http://www.nasdaqtrader.com/dynamic/SymDir/nasdaqtraded.txt"
    try:
        response = requests.get(url, verify=False)
        response.raise_for_status()  # Raise exception if the request failed
        data = StringIO(response.text)
        df = pd.read_csv(data, sep="|")
        # Filter out rows where 'Test Issue' is not 'N'
        df_clean = df[df['Test Issue'] == 'N']
        # Remove any potential trailer rows (often the last row contains summary info)
        df_clean = df_clean[df_clean['Symbol'].notna()]
        # Persist the full reference list to a CSV file in the provided directory
        ref_file = os.path.join(data_dir, "nasdaq_symbols_reference.csv")
        df_clean.to_csv(ref_file, index=False)
        symbols = df_clean['Symbol'].tolist()
        return symbols
    except Exception as e:
        logging.error(f"Error fetching NASDAQ traded symbols: {e}")
        return []

# %% [markdown]
# When you see the parameter `auto_adjust` in yfinance’s `download()` function, it refers to automatically adjusting historical price data for corporate actions—mainly stock splits and dividends.
#
# ### What Does Auto-Adjustment Mean?
#
# - **Stock Splits:**
#   When a company splits its stock (e.g., a 2-for-1 split), the number of shares increases while the share price decreases proportionally. For instance, if a stock priced at \$100 splits 2-for-1, the new price will be around \$50. Without adjustment, the historical data would show a sudden drop in price on the split date, which could be misleading if you’re analyzing trends over time.
#
# - **Dividends:**
#   Dividends can also affect the raw price data. If you reinvest dividends or need to calculate total returns, it’s useful to have prices that reflect those cash distributions.
#
# ### Why Adjust Prices?
#
# When `auto_adjust=True` is set (the default in recent versions), yfinance automatically transforms the raw price data so that historical prices are consistent over time. This means:
#
# - **Continuity in the Price Series:**
#   The historical prices are modified to "smooth out" the effect of splits and dividends. This makes it easier to compute returns or compare prices over long periods without being distorted by corporate actions.
#
# - **Simplified Analysis:**
#   Analysts and investors often need adjusted prices to accurately calculate metrics like growth rates, returns, or moving averages. With adjusted prices, you don’t have to manually correct the data for splits or dividends.
#
# ### The Warning Message
#
# The warning
# ```
# YF.download() has changed argument auto_adjust default to True
# ```
# is simply notifying you that the default behavior has changed. If you need the raw, unadjusted data (for example, if you want to see the exact trading prices as reported without any modification), you would now need to explicitly set `auto_adjust=False`. Otherwise, yfinance will automatically adjust the data for you.
#
# ### Summary
#
# - **With `auto_adjust=True`:**
#   You receive price data that’s been normalized for stock splits and dividends, which is usually what you want for long-term analysis.
#
# - **With `auto_adjust=False`:**
#   You get the raw data, which might show sudden jumps or drops due to corporate actions—this is useful if you need to see the actual trading history without adjustments.

# %%
def download_symbol_data(symbol, period="max"):
    """
    Download historical data for a single symbol using yfinance.
    Returns a tuple: (symbol, DataFrame or None)
    Passes the global_session to reuse connections.
    """
    try:
        auto_adjust_prices = True #Turn to False for unadjusted data...
        # data = yf.download(symbol, period=period, progress=False, session=global_session, auto_adjust = auto_adjust_prices) #using global_session seems to be slowing things down...
        data = yf.download(symbol, period=period, progress=False, auto_adjust = auto_adjust_prices)
        return symbol, data
    except Exception as e:
        logging.error(f"Error downloading data for {symbol}: {e}")
        return symbol, None

# %%
def classify_symbol(symbol):
    """
    Classify the symbol as 'ETF' or 'Stock' using yfinance Ticker info.
    Passes the global_session so that requests use the custom connection pool.
    If classification fails or is unknown, returns "Unknown".
    """
    try:
        ticker = yf.Ticker(symbol, session=global_session)
        info = ticker.info
        qtype = info.get("quoteType", None)
        if qtype == "ETF":
            return "ETF"
        elif qtype == "EQUITY":
            return "Stock"
        else:
            logging.error(f"Unknown or missing quoteType for {symbol}. Info: {info}")
            return "Unknown"
    except Exception as e:
        logging.error(f"Error classifying symbol {symbol}: {e}")
        return "Unknown"

# %%
# Create the main data directory first
base_dir = "data"
os.makedirs(base_dir, exist_ok=True)

# %%
# Fetch NASDAQ traded symbols and persist the reference list
symbols = get_nasdaq_symbols(base_dir)
if not symbols:
    print("No symbols found. Please check errors.log for details.")
print(f"Found {len(symbols)} traded symbols on NASDAQ. Reference list saved to {os.path.join(base_dir, 'nasdaq_symbols_reference.csv')}")
# Out:
# Found 11238 traded symbols on NASDAQ. Reference list saved to data\nasdaq_symbols_reference.csv

# %%
# Create classification subdirectories inside the data folder
folders = {
    "ETF": os.path.join(base_dir, "ETF"),
    "Stock": os.path.join(base_dir, "Stock"),
    "Unknown": os.path.join(base_dir, "Unknown")
}
for folder in folders.values():
    os.makedirs(folder, exist_ok=True)

# %%
# Dictionary to store downloaded data (if needed)
all_data = {}

# %%
# Set up ThreadPoolExecutor for parallel downloads
max_workers = 8  # adjust based on your system/network speed

# %%
# Set up ThreadPoolExecutor for parallel downloads
with ThreadPoolExecutor(max_workers=max_workers) as executor:
    future_to_symbol = {executor.submit(download_symbol_data, sym): sym for sym in symbols}
    
    for future in as_completed(future_to_symbol):
        symbol = future_to_symbol[future]
        try:
            sym, data = future.result()
            if data is not None and not data.empty:
                # Classify the symbol (ETF or Stock)
                classification = classify_symbol(sym)
                if classification not in folders:
                    classification = "Unknown"
                
                # Save data to CSV in the corresponding folder
                file_path = os.path.join(folders[classification], f"{sym}.csv")
                data.to_csv(file_path)
                all_data[sym] = data
                print(f"Downloaded and saved data for {sym} in folder '{classification}'")
            else:
                error_msg = f"No data available for {sym}"
                logging.error(error_msg)
                print(error_msg)
        except Exception as exc:
            logging.error(f"{symbol} generated an exception: {exc}")
            print(f"{symbol} generated an exception. See errors.log for details.")
# Out:
# Downloaded and saved data for AAA in folder 'Unknown'
# Downloaded and saved data for A in folder 'Unknown'
# Downloaded and saved data for AAAU in folder 'Unknown'
# Downloaded and saved data for AA in folder 'Unknown'
# Downloaded and saved data for AACT in folder 'Unknown'
# Downloaded and saved data for AACT.U in folder 'Unknown'
# Downloaded and saved data for AACT.W in folder 'Unknown'
# Downloaded and saved data for AACBU in folder 'Unknown'
# Downloaded and saved data for AACG in folder 'Unknown'
# Downloaded and saved data for AADR in folder 'Unknown'
# Downloaded and saved data for AAME in folder 'Unknown'
# Downloaded and saved data for AAL in folder 'Unknown'
# Downloaded and saved data for AAM in folder 'Unknown'
# Downloaded and saved data for AAM.W in folder 'Unknown'
# Downloaded and saved data for AAMI in folder 'Unknown'
# Downloaded and saved data for AAM.U in folder 'Unknown'
# Downloaded and saved data for AAOI in folder 'Unknown'
# Downloaded and saved data for AAPB in folder 'Unknown'
# Downloaded and saved data for AAPG in folder 'Unknown'
# Downloaded and saved data for AAPD in folder 'Unknown'
# Downloaded and saved data for AAPW in folder 'Unknown'
# Downloaded and saved data for AAON in folder 'Unknown'
# Downloaded and saved data for AAPX in folder 'Unknown'
# Downloaded and saved data for AAP in folder 'Unknown'
# Downloaded and saved data for AAPU in folder 'Unknown'
# Downloaded and saved data for AAPL in folder 'Unknown'
# Downloaded and saved data for AAPR in folder 'Unknown'
# Downloaded and saved data for AARD in folder 'Unknown'
# Downloaded and saved data for ABAT in folder 'Unknown'
# Downloaded and saved data for AB in folder 'Unknown'
# Downloaded and saved data for AAVM in folder 'Unknown'
# Downloaded and saved data for AAXJ in folder 'Unknown'
# Downloaded and saved data for AAT in folder 'Unknown'
# Downloaded and saved data for ABBV in folder 'Unknown'
# Downloaded and saved data for ABFL in folder 'Unknown'
# Downloaded and saved data for AAPY in folder 'Unknown'
# Downloaded and saved data for ABCS in folder 'Unknown'
# Downloaded and saved data for ABCB in folder 'Unknown'
# Downloaded and saved data for ABEV in folder 'Unknown'
# Downloaded and saved data for ABEQ in folder 'Unknown'
# Downloaded and saved data for ABCL in folder 'Unknown'
# Downloaded and saved data for ABEO in folder 'Unknown'
# No data available for ABL
# No data available for ABLLW
# No data available for ABG
# Downloaded and saved data for ABLG in folder 'Unknown'
# Downloaded and saved data for ABLLL in folder 'Unknown'
# Downloaded and saved data for ABM in folder 'Unknown'
# No data available for ABLD
# Downloaded and saved data for ABLVW in folder 'Unknown'
# Downloaded and saved data for ABLS in folder 'Unknown'
# No data available for ABLV
# Downloaded and saved data for ABNB in folder 'Unknown'
# No data available for ABHY
# Downloaded and saved data for ABR$E in folder 'Unknown'
# Downloaded and saved data for ABR$D in folder 'Unknown'
# Downloaded and saved data for ABP in folder 'Unknown'
# Downloaded and saved data for ABNY in folder 'Unknown'
# Downloaded and saved data for ABR in folder 'Unknown'
# Downloaded and saved data for ABOS in folder 'Unknown'
# Downloaded and saved data for ABOT in folder 'Unknown'
# Downloaded and saved data for ABPWW in folder 'Unknown'
# Downloaded and saved data for ABTS in folder 'Unknown'
# Downloaded and saved data for ABT in folder 'Unknown'
# Downloaded and saved data for ABVE in folder 'Unknown'
# Downloaded and saved data for ABVEW in folder 'Unknown'
# Downloaded and saved data for ABR$F in folder 'Unknown'
# Downloaded and saved data for ABVX in folder 'Unknown'
# Downloaded and saved data for ABSI in folder 'Unknown'
# Downloaded and saved data for ABVC in folder 'Unknown'
# Downloaded and saved data for ABUS in folder 'Unknown'
# Downloaded and saved data for ACA in folder 'Unknown'
# Downloaded and saved data for AC in folder 'Unknown'
# Downloaded and saved data for ACAD in folder 'Unknown'
# Downloaded and saved data for ACCO in folder 'Unknown'
# Downloaded and saved data for ACCS in folder 'Unknown'
# Downloaded and saved data for ACCD in folder 'Unknown'
# Downloaded and saved data for ACDC in folder 'Unknown'
# Downloaded and saved data for ACB in folder 'Unknown'
# Downloaded and saved data for ACGL in folder 'Unknown'
# Downloaded and saved data for ACGR in folder 'Unknown'
# Downloaded and saved data for ACHR in folder 'Unknown'
# Downloaded and saved data for ACGLO in folder 'Unknown'
# Downloaded and saved data for ACEL in folder 'Unknown'
# Downloaded and saved data for ACHC in folder 'Unknown'
# Downloaded and saved data for ACES in folder 'Unknown'
# Downloaded and saved data for ACGLN in folder 'Unknown'
# Downloaded and saved data for ACET in folder 'Unknown'
# Downloaded and saved data for ACIW in folder 'Unknown'
# Downloaded and saved data for ACHR.W in folder 'Unknown'
# Downloaded and saved data for ACIC in folder 'Unknown'
# Downloaded and saved data for ACHV in folder 'Unknown'
# Downloaded and saved data for ACI in folder 'Unknown'
# Downloaded and saved data for ACLS in folder 'Unknown'
# Downloaded and saved data for ACM in folder 'Unknown'
# Downloaded and saved data for ACLC in folder 'Unknown'
# Downloaded and saved data for ACIO in folder 'Unknown'
# Downloaded and saved data for ACIU in folder 'Unknown'
# Downloaded and saved data for ACMR in folder 'Unknown'
# Downloaded and saved data for ACOG in folder 'Unknown'
# Downloaded and saved data for ACONW in folder 'Unknown'
# Downloaded and saved data for ACON in folder 'Unknown'
# Downloaded and saved data for ACNT in folder 'Unknown'
# Downloaded and saved data for ACLX in folder 'Unknown'
# Downloaded and saved data for ACN in folder 'Unknown'
# Downloaded and saved data for ACNB in folder 'Unknown'
# Downloaded and saved data for ACLO in folder 'Unknown'
# Downloaded and saved data for ACP$A in folder 'Unknown'
# Downloaded and saved data for ACR$C in folder 'Unknown'
# Downloaded and saved data for ACRS in folder 'Unknown'
# Downloaded and saved data for ACRE in folder 'Unknown'
# Downloaded and saved data for ACRV in folder 'Unknown'
# Downloaded and saved data for ACR$D in folder 'Unknown'
# Downloaded and saved data for ACR in folder 'Unknown'
# Downloaded and saved data for ACT in folder 'Unknown'
# Downloaded and saved data for ACTU in folder 'Unknown'
# Downloaded and saved data for ACTG in folder 'Unknown'
# Downloaded and saved data for ACU in folder 'Unknown'
# Downloaded and saved data for ACTV in folder 'Unknown'
# Downloaded and saved data for ACVF in folder 'Unknown'
# Downloaded and saved data for ACSI in folder 'Unknown'
# Downloaded and saved data for ACP in folder 'Unknown'
# Downloaded and saved data for ACWV in folder 'Unknown'
# Downloaded and saved data for ACV in folder 'Unknown'
# Downloaded and saved data for ACVA in folder 'Unknown'
# Downloaded and saved data for ACWI in folder 'Unknown'
# Downloaded and saved data for ACWX in folder 'Unknown'
# Downloaded and saved data for ADAP in folder 'Unknown'
# Downloaded and saved data for ADBE in folder 'Unknown'
# Downloaded and saved data for ADAG in folder 'Unknown'
# No data available for ADC$A
# No data available for ADBG
# No data available for ADC
# No data available for ADCT
# Downloaded and saved data for ADIV in folder 'Unknown'
# Downloaded and saved data for ACXP in folder 'Unknown'
# Downloaded and saved data for ADGM in folder 'Unknown'
# Downloaded and saved data for ADFI in folder 'Unknown'
# Downloaded and saved data for ADEA in folder 'Unknown'
# Downloaded and saved data for ADI in folder 'Unknown'
# Downloaded and saved data for ADD in folder 'Unknown'
# Downloaded and saved data for ADIL in folder 'Unknown'
# Downloaded and saved data for ADNWW in folder 'Unknown'
# Downloaded and saved data for ADMA in folder 'Unknown'
# Downloaded and saved data for ADME in folder 'Unknown'
# Downloaded and saved data for ADPT in folder 'Unknown'
# Downloaded and saved data for ADPV in folder 'Unknown'
# Downloaded and saved data for ADNT in folder 'Unknown'
# Downloaded and saved data for ADP in folder 'Unknown'
# Downloaded and saved data for ADN in folder 'Unknown'
# Downloaded and saved data for ADM in folder 'Unknown'
# No data available for ADUR
# No data available for ADSEW
# No data available for ADTN
# No data available for ADT
# No data available for ADSE
# Downloaded and saved data for ADVB in folder 'Unknown'
# Downloaded and saved data for ADSK in folder 'Unknown'
# Downloaded and saved data for ADUS in folder 'Unknown'
# Downloaded and saved data for ADV in folder 'Unknown'
# Downloaded and saved data for ADTX in folder 'Unknown'
# Downloaded and saved data for ADXN in folder 'Unknown'
# Downloaded and saved data for AEFC in folder 'Unknown'
# Downloaded and saved data for ADVM in folder 'Unknown'
# Downloaded and saved data for ADVWW in folder 'Unknown'
# Downloaded and saved data for AEF in folder 'Unknown'
# Downloaded and saved data for AEE in folder 'Unknown'
# Downloaded and saved data for ADX in folder 'Unknown'
# Downloaded and saved data for AEM in folder 'Unknown'
# Downloaded and saved data for AEHL in folder 'Unknown'
# Downloaded and saved data for AEMD in folder 'Unknown'
# Downloaded and saved data for AEHR in folder 'Unknown'
# Downloaded and saved data for AEIS in folder 'Unknown'
# Downloaded and saved data for AEI in folder 'Unknown'
# Downloaded and saved data for ADVE in folder 'Unknown'
# Downloaded and saved data for AEG in folder 'Unknown'
# Downloaded and saved data for AERTW in folder 'Unknown'
# Downloaded and saved data for AER in folder 'Unknown'
# Downloaded and saved data for AERT in folder 'Unknown'
# Downloaded and saved data for AEO in folder 'Unknown'
# Downloaded and saved data for AENT in folder 'Unknown'
# Downloaded and saved data for AEON in folder 'Unknown'
# Downloaded and saved data for AEP in folder 'Unknown'
# Downloaded and saved data for AENTW in folder 'Unknown'
# Downloaded and saved data for AESR in folder 'Unknown'
# Downloaded and saved data for AES in folder 'Unknown'
# Downloaded and saved data for AETH in folder 'Unknown'
# Downloaded and saved data for AEVAW in folder 'Unknown'
# Downloaded and saved data for AEYE in folder 'Unknown'
# Downloaded and saved data for AEVA in folder 'Unknown'
# Downloaded and saved data for AESI in folder 'Unknown'
# Downloaded and saved data for AFG in folder 'Unknown'
# Downloaded and saved data for AFCG in folder 'Unknown'
# Downloaded and saved data for AFGB in folder 'Unknown'
# Downloaded and saved data for AFB in folder 'Unknown'
# Downloaded and saved data for AFJK in folder 'Unknown'
# Downloaded and saved data for AFIX in folder 'Unknown'
# Downloaded and saved data for AFBI in folder 'Unknown'
# Downloaded and saved data for AFL in folder 'Unknown'
# Downloaded and saved data for AFIF in folder 'Unknown'
# Downloaded and saved data for AFGE in folder 'Unknown'
# Downloaded and saved data for AFK in folder 'Unknown'
# Downloaded and saved data for AFGC in folder 'Unknown'
# Downloaded and saved data for AFJKU in folder 'Unknown'
# Downloaded and saved data for AFGD in folder 'Unknown'
# Downloaded and saved data for AFJKR in folder 'Unknown'
# Downloaded and saved data for AFSM in folder 'Unknown'
# Downloaded and saved data for AFMD in folder 'Unknown'
# Downloaded and saved data for AFRI in folder 'Unknown'
# Downloaded and saved data for AFRM in folder 'Unknown'
# Downloaded and saved data for AFMC in folder 'Unknown'
# Downloaded and saved data for AFLG in folder 'Unknown'
# Downloaded and saved data for AFRIW in folder 'Unknown'
# Downloaded and saved data for AFSC in folder 'Unknown'
# No data available for AG
# No data available for AGCO
# No data available for AGFY
# No data available for AGEM
# No data available for AGAE
# No data available for AFYA
# No data available for AGD
# Downloaded and saved data for AGI in folder 'Unknown'
# Downloaded and saved data for AGG in folder 'Unknown'
# Downloaded and saved data for AGGH in folder 'Unknown'
# Downloaded and saved data for AGGY in folder 'Unknown'
# Downloaded and saved data for AGH in folder 'Unknown'
# Downloaded and saved data for AGIH in folder 'Unknown'
# Downloaded and saved data for AGEN in folder 'Unknown'
# Downloaded and saved data for AGGS in folder 'Unknown'
# Downloaded and saved data for AGL in folder 'Unknown'
# Downloaded and saved data for AGM$E in folder 'Unknown'
# Downloaded and saved data for AGM$D in folder 'Unknown'
# Downloaded and saved data for AGIO in folder 'Unknown'
# Downloaded and saved data for AGIX in folder 'Unknown'
# Downloaded and saved data for AGM$F in folder 'Unknown'
# Downloaded and saved data for AGM$G in folder 'Unknown'
# Downloaded and saved data for AGM in folder 'Unknown'
# Downloaded and saved data for AGM.A in folder 'Unknown'
# Downloaded and saved data for AGMI in folder 'Unknown'
# Downloaded and saved data for AGNC in folder 'Unknown'
# Downloaded and saved data for AGNCM in folder 'Unknown'
# Downloaded and saved data for AGNCP in folder 'Unknown'
# Downloaded and saved data for AGNCN in folder 'Unknown'
# Downloaded and saved data for AGMH in folder 'Unknown'
# Downloaded and saved data for AGNCL in folder 'Unknown'
# Downloaded and saved data for AGNCO in folder 'Unknown'
# Downloaded and saved data for AGO in folder 'Unknown'
# Downloaded and saved data for AGQ in folder 'Unknown'
# Downloaded and saved data for AGNG in folder 'Unknown'
# Downloaded and saved data for AGQI in folder 'Unknown'
# Downloaded and saved data for AGRH in folder 'Unknown'
# Downloaded and saved data for AGOX in folder 'Unknown'
# Downloaded and saved data for AGRO in folder 'Unknown'
# Downloaded and saved data for AGZ in folder 'Unknown'
# Downloaded and saved data for AHCO in folder 'Unknown'
# Downloaded and saved data for AGYS in folder 'Unknown'
# Downloaded and saved data for AGRI in folder 'Unknown'
# Downloaded and saved data for AGS in folder 'Unknown'
# Downloaded and saved data for AHG in folder 'Unknown'
# Downloaded and saved data for AGX in folder 'Unknown'
# Downloaded and saved data for AHL$D in folder 'Unknown'
# Downloaded and saved data for AGZD in folder 'Unknown'
# Downloaded and saved data for AHH in folder 'Unknown'
# Downloaded and saved data for AHH$A in folder 'Unknown'
# Downloaded and saved data for AHL$E in folder 'Unknown'
# Downloaded and saved data for AHL$F in folder 'Unknown'
# Downloaded and saved data for AHT$H in folder 'Unknown'
# Downloaded and saved data for AHLT in folder 'Unknown'
# Downloaded and saved data for AHT$D in folder 'Unknown'
# Downloaded and saved data for AHR in folder 'Unknown'
# Downloaded and saved data for AHT$G in folder 'Unknown'
# No data available for AIA
# No data available for AHYB
# Downloaded and saved data for AIEV in folder 'Unknown'
# Downloaded and saved data for AHT$I in folder 'Unknown'
# Downloaded and saved data for AIEQ in folder 'Unknown'
# Downloaded and saved data for AIBU in folder 'Unknown'
# Downloaded and saved data for AHT in folder 'Unknown'
# Downloaded and saved data for AHT$F in folder 'Unknown'
# Downloaded and saved data for AI in folder 'Unknown'
# Downloaded and saved data for AIBD in folder 'Unknown'
# No data available for AIFU
# No data available for AIFEU
# Downloaded and saved data for AIFD in folder 'Unknown'
# Downloaded and saved data for AIFE in folder 'Unknown'
# Downloaded and saved data for AIFF in folder 'Unknown'
# Downloaded and saved data for AIMBU in folder 'Unknown'
# Downloaded and saved data for AIFER in folder 'Unknown'
# No data available for AIG
# No data available for AIMAU
# No data available for AIHS
# Downloaded and saved data for AIO in folder 'Unknown'
# Downloaded and saved data for AIMDW in folder 'Unknown'
# Downloaded and saved data for AIM in folder 'Unknown'
# Downloaded and saved data for AIN in folder 'Unknown'
# Downloaded and saved data for AINP in folder 'Unknown'
# Downloaded and saved data for AIMAW in folder 'Unknown'
# Downloaded and saved data for AIOT in folder 'Unknown'
# Downloaded and saved data for AIMD in folder 'Unknown'
# Downloaded and saved data for AIP in folder 'Unknown'
# Downloaded and saved data for AIQ in folder 'Unknown'
# Downloaded and saved data for AIRE in folder 'Unknown'
# Downloaded and saved data for AIPI in folder 'Unknown'
# Downloaded and saved data for AIRJW in folder 'Unknown'
# Downloaded and saved data for AIRI in folder 'Unknown'
# Downloaded and saved data for AIR in folder 'Unknown'
# Downloaded and saved data for AIRJ in folder 'Unknown'
# Downloaded and saved data for AIRG in folder 'Unknown'
# Downloaded and saved data for AIRL in folder 'Unknown'
# No data available for AIRR
# No data available for AIRS
# Downloaded and saved data for AISP in folder 'Unknown'
# No data available for AISPW
# Downloaded and saved data for AIRT in folder 'Unknown'
# No data available for AIS
# Downloaded and saved data for AIT in folder 'Unknown'
# Downloaded and saved data for AITR in folder 'Unknown'
# No data available for AIRTP
# Downloaded and saved data for AIYY in folder 'Unknown'
# Downloaded and saved data for AIXI in folder 'Unknown'
# Downloaded and saved data for AITRU in folder 'Unknown'
# Downloaded and saved data for AIV in folder 'Unknown'
# Downloaded and saved data for AIVL in folder 'Unknown'
# Downloaded and saved data for AITRR in folder 'Unknown'
# Downloaded and saved data for AIVI in folder 'Unknown'
# Downloaded and saved data for AIVC in folder 'Unknown'
# Downloaded and saved data for AJAN in folder 'Unknown'
# Downloaded and saved data for AKAN in folder 'Unknown'
# Downloaded and saved data for AJG in folder 'Unknown'
# Downloaded and saved data for AJUL in folder 'Unknown'
# Downloaded and saved data for AKAM in folder 'Unknown'
# Downloaded and saved data for AIZ in folder 'Unknown'
# Downloaded and saved data for AKO.B in folder 'Unknown'
# Downloaded and saved data for AKBA in folder 'Unknown'
# Downloaded and saved data for AKA in folder 'Unknown'
# Downloaded and saved data for AKO.A in folder 'Unknown'
# Downloaded and saved data for AKRO in folder 'Unknown'
# Downloaded and saved data for AL in folder 'Unknown'
# Downloaded and saved data for ALAB in folder 'Unknown'
# Downloaded and saved data for ALAI in folder 'Unknown'
# Downloaded and saved data for ALAR in folder 'Unknown'
# Downloaded and saved data for AKYA in folder 'Unknown'
# Downloaded and saved data for AKTX in folder 'Unknown'
# Downloaded and saved data for AKR in folder 'Unknown'
# Downloaded and saved data for ALBT in folder 'Unknown'
# Downloaded and saved data for ALB$A in folder 'Unknown'
# Downloaded and saved data for ALC in folder 'Unknown'
# Downloaded and saved data for AIZN in folder 'Unknown'
# Downloaded and saved data for ALCYW in folder 'Unknown'
# Downloaded and saved data for ALDX in folder 'Unknown'
# Downloaded and saved data for ALDF in folder 'Unknown'
# Downloaded and saved data for ALDFU in folder 'Unknown'
# Downloaded and saved data for ALDFW in folder 'Unknown'
# Downloaded and saved data for ALCYU in folder 'Unknown'
# Downloaded and saved data for ALB in folder 'Unknown'
# Downloaded and saved data for ALCO in folder 'Unknown'
# Downloaded and saved data for ALEC in folder 'Unknown'
# Downloaded and saved data for ALCY in folder 'Unknown'
# Downloaded and saved data for ALFUW in folder 'Unknown'
# Downloaded and saved data for ALE in folder 'Unknown'
# Downloaded and saved data for ALF in folder 'Unknown'
# Downloaded and saved data for ALFUU in folder 'Unknown'
# Downloaded and saved data for ALEX in folder 'Unknown'
# Downloaded and saved data for ALG in folder 'Unknown'
# Downloaded and saved data for ALK in folder 'Unknown'
# Downloaded and saved data for ALHC in folder 'Unknown'
# Downloaded and saved data for ALGM in folder 'Unknown'
# Downloaded and saved data for ALIT in folder 'Unknown'
# Downloaded and saved data for ALGN in folder 'Unknown'
# No data available for ALL
# Downloaded and saved data for ALGT in folder 'Unknown'
# No data available for ALKS
# Downloaded and saved data for ALGS in folder 'Unknown'
# Downloaded and saved data for ALL$I in folder 'Unknown'
# Downloaded and saved data for ALLK in folder 'Unknown'
# Downloaded and saved data for ALLO in folder 'Unknown'
# Downloaded and saved data for ALLE in folder 'Unknown'
# Downloaded and saved data for ALL$B in folder 'Unknown'
# Downloaded and saved data for ALL$H in folder 'Unknown'
# Downloaded and saved data for ALKT in folder 'Unknown'
# Downloaded and saved data for ALL$J in folder 'Unknown'
# Downloaded and saved data for ALOT in folder 'Unknown'
# No data available for ALLW
# No data available for ALLR
# Downloaded and saved data for ALLY in folder 'Unknown'
# Downloaded and saved data for ALNT in folder 'Unknown'
# No data available for ALRM
# No data available for ALMS
# No data available for ALRS
# No data available for ALSN
# No data available for ALNY
# Downloaded and saved data for ALTO in folder 'Unknown'
# Downloaded and saved data for ALTI in folder 'Unknown'
# Downloaded and saved data for ALTR in folder 'Unknown'
# Downloaded and saved data for ALLT in folder 'Unknown'
# Downloaded and saved data for ALTG$A in folder 'Unknown'
# Downloaded and saved data for ALT in folder 'Unknown'
# Downloaded and saved data for ALTL in folder 'Unknown'
# Downloaded and saved data for ALTG in folder 'Unknown'
# Downloaded and saved data for ALV in folder 'Unknown'
# Downloaded and saved data for ALUR in folder 'Unknown'
# Downloaded and saved data for ALUR.W in folder 'Unknown'
# Downloaded and saved data for ALVOW in folder 'Unknown'
# Downloaded and saved data for ALX in folder 'Unknown'
# Downloaded and saved data for ALVO in folder 'Unknown'
# Downloaded and saved data for ALTY in folder 'Unknown'
# Downloaded and saved data for ALTS in folder 'Unknown'
# Downloaded and saved data for AMBC in folder 'Unknown'
# Downloaded and saved data for ALZN in folder 'Unknown'
# Downloaded and saved data for AMAX in folder 'Unknown'
# Downloaded and saved data for AM in folder 'Unknown'
# Downloaded and saved data for AMBI in folder 'Unknown'
# Downloaded and saved data for AMBA in folder 'Unknown'
# Downloaded and saved data for AMAT in folder 'Unknown'
# Downloaded and saved data for AMAL in folder 'Unknown'
# Downloaded and saved data for AMBP.W in folder 'Unknown'
# Downloaded and saved data for ALXO in folder 'Unknown'
# Downloaded and saved data for AMCX in folder 'Unknown'
# Downloaded and saved data for AMBP in folder 'Unknown'
# Downloaded and saved data for AMD in folder 'Unknown'
# Downloaded and saved data for AMC in folder 'Unknown'
# Downloaded and saved data for AMBO in folder 'Unknown'
# Downloaded and saved data for AMCR in folder 'Unknown'
# Downloaded and saved data for AMBI.W in folder 'Unknown'
# Downloaded and saved data for AMBR in folder 'Unknown'
# Downloaded and saved data for AMDY in folder 'Unknown'
# Downloaded and saved data for AMDS in folder 'Unknown'
# Downloaded and saved data for AMDD in folder 'Unknown'
# Downloaded and saved data for AMDL in folder 'Unknown'
# Downloaded and saved data for AMED in folder 'Unknown'
# Downloaded and saved data for AMDG in folder 'Unknown'
# Downloaded and saved data for AMG in folder 'Unknown'
# Downloaded and saved data for AME in folder 'Unknown'
# Downloaded and saved data for AMH$G in folder 'Unknown'
# Downloaded and saved data for AMID in folder 'Unknown'
# Downloaded and saved data for AMJB in folder 'Unknown'
# Downloaded and saved data for AMKR in folder 'Unknown'
# Downloaded and saved data for AMIX in folder 'Unknown'
# Downloaded and saved data for AMH in folder 'Unknown'
# Downloaded and saved data for AMGN in folder 'Unknown'
# Downloaded and saved data for AMH$H in folder 'Unknown'
# Downloaded and saved data for AMLP in folder 'Unknown'
# No data available for AMP
# No data available for AMPG
# No data available for AMODW
# No data available for AMOD
# No data available for AMOM
# No data available for AMPGW
# No data available for AMN
# Downloaded and saved data for AMPS in folder 'Unknown'
# Downloaded and saved data for AMLX in folder 'Unknown'
# Downloaded and saved data for AMPX in folder 'Unknown'
# Downloaded and saved data for AMPX.W in folder 'Unknown'
# Downloaded and saved data for AMPH in folder 'Unknown'
# Downloaded and saved data for AMPY in folder 'Unknown'
# Downloaded and saved data for AMR in folder 'Unknown'
# Downloaded and saved data for AMPL in folder 'Unknown'
# Downloaded and saved data for AMRK in folder 'Unknown'
# Downloaded and saved data for AMS in folder 'Unknown'
# Downloaded and saved data for AMRX in folder 'Unknown'
# Downloaded and saved data for AMRC in folder 'Unknown'
# Downloaded and saved data for AMRN in folder 'Unknown'
# Downloaded and saved data for AMSC in folder 'Unknown'
# Downloaded and saved data for AMTD in folder 'Unknown'
# Downloaded and saved data for AMST in folder 'Unknown'
# Downloaded and saved data for AMTX in folder 'Unknown'
# Downloaded and saved data for AMTM in folder 'Unknown'
# Downloaded and saved data for AMT in folder 'Unknown'
# Downloaded and saved data for AMSF in folder 'Unknown'
# Downloaded and saved data for AMTB in folder 'Unknown'
# Downloaded and saved data for AMWD in folder 'Unknown'
# Downloaded and saved data for AMUU in folder 'Unknown'
# Downloaded and saved data for AMUB in folder 'Unknown'
# Downloaded and saved data for AMZD in folder 'Unknown'
# Downloaded and saved data for AMZA in folder 'Unknown'
# Downloaded and saved data for AMWL in folder 'Unknown'
# Downloaded and saved data for AMX in folder 'Unknown'
# Downloaded and saved data for AMZN in folder 'Unknown'
# Downloaded and saved data for AMZP in folder 'Unknown'
# Downloaded and saved data for ANAB in folder 'Unknown'
# Downloaded and saved data for AMZY in folder 'Unknown'
# Downloaded and saved data for AMZU in folder 'Unknown'
# Downloaded and saved data for ANET in folder 'Unknown'
# Downloaded and saved data for ANEB in folder 'Unknown'
# Downloaded and saved data for AMZZ in folder 'Unknown'
# Downloaded and saved data for AN in folder 'Unknown'
# Downloaded and saved data for ANDE in folder 'Unknown'
# Downloaded and saved data for ANGHW in folder 'Unknown'
# Downloaded and saved data for ANF in folder 'Unknown'
# Downloaded and saved data for ANGI in folder 'Unknown'
# Downloaded and saved data for ANG$B in folder 'Unknown'
# Downloaded and saved data for ANGL in folder 'Unknown'
# Downloaded and saved data for ANG$D in folder 'Unknown'
# Downloaded and saved data for ANEW in folder 'Unknown'
# Downloaded and saved data for ANGH in folder 'Unknown'
# Downloaded and saved data for ANIP in folder 'Unknown'
# Downloaded and saved data for ANIK in folder 'Unknown'
# Downloaded and saved data for ANGO in folder 'Unknown'
# Downloaded and saved data for ANL in folder 'Unknown'
# Downloaded and saved data for ANNX in folder 'Unknown'
# Downloaded and saved data for ANNA in folder 'Unknown'
# Downloaded and saved data for ANIX in folder 'Unknown'
# Downloaded and saved data for ANNAW in folder 'Unknown'
# Downloaded and saved data for ANRO in folder 'Unknown'
# Downloaded and saved data for ANSC in folder 'Unknown'
# Downloaded and saved data for ANSCW in folder 'Unknown'
# Downloaded and saved data for ANSS in folder 'Unknown'
# Downloaded and saved data for AOA in folder 'Unknown'
# Downloaded and saved data for ANTE in folder 'Unknown'
# Downloaded and saved data for ANTX in folder 'Unknown'
# Downloaded and saved data for AOD in folder 'Unknown'
# Downloaded and saved data for ANSCU in folder 'Unknown'
# Downloaded and saved data for AOCT in folder 'Unknown'
# Downloaded and saved data for ANVS in folder 'Unknown'
# Downloaded and saved data for ANY in folder 'Unknown'
# Downloaded and saved data for AORT in folder 'Unknown'
# Downloaded and saved data for AOHY in folder 'Unknown'
# Downloaded and saved data for AOK in folder 'Unknown'
# Downloaded and saved data for AOM in folder 'Unknown'
# Downloaded and saved data for AON in folder 'Unknown'
# Downloaded and saved data for AOR in folder 'Unknown'
# Downloaded and saved data for AOMR in folder 'Unknown'
# Downloaded and saved data for AOMN in folder 'Unknown'
# Downloaded and saved data for AOS in folder 'Unknown'
# Downloaded and saved data for AOTG in folder 'Unknown'
# Downloaded and saved data for APAM in folder 'Unknown'
# Downloaded and saved data for AOSL in folder 'Unknown'
# Downloaded and saved data for AOUT in folder 'Unknown'
# Downloaded and saved data for AP in folder 'Unknown'
# Downloaded and saved data for APA in folder 'Unknown'
# Downloaded and saved data for AP.W in folder 'Unknown'
# Downloaded and saved data for APCB in folder 'Unknown'
# Downloaded and saved data for APCXW in folder 'Unknown'
# Downloaded and saved data for APD in folder 'Unknown'
# Downloaded and saved data for APED in folder 'Unknown'
# Downloaded and saved data for APCX in folder 'Unknown'
# Downloaded and saved data for APDN in folder 'Unknown'
# Downloaded and saved data for APEI in folder 'Unknown'
# Downloaded and saved data for APG in folder 'Unknown'
# Downloaded and saved data for APIE in folder 'Unknown'
# Downloaded and saved data for APGE in folder 'Unknown'
# Downloaded and saved data for APLD in folder 'Unknown'
# Downloaded and saved data for APLMW in folder 'Unknown'
# Downloaded and saved data for APLM in folder 'Unknown'
# Downloaded and saved data for API in folder 'Unknown'
# Downloaded and saved data for APH in folder 'Unknown'
# Downloaded and saved data for APLU in folder 'Unknown'
# Downloaded and saved data for APLS in folder 'Unknown'
# Downloaded and saved data for APLT in folder 'Stock'
# Downloaded and saved data for APLY in folder 'ETF'
# Downloaded and saved data for APLE in folder 'Stock'
# Downloaded and saved data for APM in folder 'Stock'
# Downloaded and saved data for APO in folder 'Stock'
# Downloaded and saved data for APMU in folder 'ETF'
# Downloaded and saved data for APOS in folder 'Stock'
# Downloaded and saved data for APOC in folder 'ETF'
# Downloaded and saved data for APOG in folder 'Stock'
# Downloaded and saved data for APRE in folder 'Stock'
# Downloaded and saved data for APPS in folder 'Stock'
# Downloaded and saved data for APRH in folder 'ETF'
# Downloaded and saved data for APPN in folder 'Stock'
# Downloaded and saved data for APO$A in folder 'Unknown'
# Downloaded and saved data for APP in folder 'Stock'
# Downloaded and saved data for APRQ in folder 'ETF'
# Downloaded and saved data for APRP in folder 'ETF'
# Downloaded and saved data for APRD in folder 'ETF'
# Downloaded and saved data for APT in folder 'Stock'
# Downloaded and saved data for APRJ in folder 'ETF'
# Downloaded and saved data for APRT in folder 'ETF'
# Downloaded and saved data for APPF in folder 'Stock'
# Downloaded and saved data for APRZ in folder 'ETF'
# Downloaded and saved data for APRW in folder 'ETF'
# Downloaded and saved data for APTO in folder 'Stock'
# Downloaded and saved data for APTV in folder 'Stock'
# Downloaded and saved data for APUE in folder 'ETF'
# Downloaded and saved data for APYX in folder 'Stock'
# Downloaded and saved data for AQLT in folder 'ETF'
# Downloaded and saved data for AQN in folder 'Stock'
# Downloaded and saved data for APWC in folder 'Stock'
# Downloaded and saved data for APVO in folder 'Stock'
# Downloaded and saved data for AQB in folder 'Stock'
# Downloaded and saved data for AQMS in folder 'Stock'
# Downloaded and saved data for AQST in folder 'Stock'
# Downloaded and saved data for ARB in folder 'ETF'
# Downloaded and saved data for AQNB in folder 'Stock'
# Downloaded and saved data for ARBB in folder 'Stock'
# Downloaded and saved data for AR in folder 'Stock'
# Downloaded and saved data for ARBE in folder 'Stock'
# Downloaded and saved data for ARAY in folder 'Stock'
# Downloaded and saved data for AQWA in folder 'ETF'
# No data available for ARCC
# Downloaded and saved data for ARBEW in folder 'Stock'
# Downloaded and saved data for ARDC in folder 'Stock'
# Downloaded and saved data for ARCO in folder 'Stock'
# Downloaded and saved data for ARCT in folder 'Stock'
# Downloaded and saved data for ARBKL in folder 'Stock'
# No data available for ARCB
# No data available for ARCM
# Downloaded and saved data for ARDT in folder 'Stock'
# Downloaded and saved data for ARDX in folder 'Stock'
# Downloaded and saved data for ARBK in folder 'Stock'
# Downloaded and saved data for AREBW in folder 'Stock'
# Downloaded and saved data for AREC in folder 'Stock'
# Downloaded and saved data for AREB in folder 'Stock'
# Downloaded and saved data for ARES in folder 'Stock'
# Downloaded and saved data for AREA in folder 'ETF'
# Downloaded and saved data for AREN in folder 'Stock'
# Downloaded and saved data for ARGD in folder 'Stock'
# Downloaded and saved data for ARE in folder 'Stock'
# Downloaded and saved data for ARKA in folder 'ETF'
# Downloaded and saved data for ARI in folder 'Stock'
# Downloaded and saved data for ARHS in folder 'Stock'
# Downloaded and saved data for ARGX in folder 'Stock'
# Downloaded and saved data for ARES$B in folder 'Unknown'
# Downloaded and saved data for ARGO$A in folder 'Unknown'
# Downloaded and saved data for ARGT in folder 'ETF'
# Downloaded and saved data for ARIS in folder 'Stock'
# Downloaded and saved data for ARKK in folder 'ETF'
# Downloaded and saved data for ARKOW in folder 'Stock'
# Downloaded and saved data for ARKB in folder 'ETF'
# Downloaded and saved data for ARKF in folder 'ETF'
# Downloaded and saved data for ARKC in folder 'ETF'
# Downloaded and saved data for ARKO in folder 'Stock'
# Downloaded and saved data for ARKG in folder 'ETF'
# Downloaded and saved data for ARKR in folder 'Stock'
# Downloaded and saved data for ARKQ in folder 'ETF'
# Downloaded and saved data for ARKD in folder 'ETF'
# Downloaded and saved data for ARKZ in folder 'ETF'
# Downloaded and saved data for ARKW in folder 'ETF'
# Downloaded and saved data for ARL in folder 'Stock'
# Downloaded and saved data for ARKY in folder 'ETF'
# Downloaded and saved data for ARMH in folder 'ETF'
# Downloaded and saved data for ARM in folder 'Stock'
# Downloaded and saved data for ARKX in folder 'ETF'
# Downloaded and saved data for ARMK in folder 'Stock'
# Downloaded and saved data for ARLU in folder 'ETF'
# Downloaded and saved data for ARLO in folder 'Stock'
# Downloaded and saved data for ARLP in folder 'Stock'
# Downloaded and saved data for ARMG in folder 'Stock'
# Downloaded and saved data for ARQ in folder 'Stock'
# Downloaded and saved data for ARMN in folder 'Stock'
# Downloaded and saved data for AROW in folder 'Stock'
# Downloaded and saved data for ARMP in folder 'Stock'
# Downloaded and saved data for ARQQ in folder 'Stock'
# Downloaded and saved data for ARP in folder 'ETF'
# Downloaded and saved data for ARMU in folder 'ETF'
# Downloaded and saved data for AROC in folder 'Stock'
# Downloaded and saved data for ARR$C in folder 'Unknown'
# Downloaded and saved data for ARR in folder 'Stock'
# Downloaded and saved data for ARTNA in folder 'Stock'
# Downloaded and saved data for ARTL in folder 'Stock'
# Downloaded and saved data for ARQQW in folder 'Stock'
# Downloaded and saved data for ARRY in folder 'Stock'
# Downloaded and saved data for ARTV in folder 'Stock'
# Downloaded and saved data for ARQT in folder 'Stock'
# Downloaded and saved data for ARVR in folder 'ETF'
# Downloaded and saved data for AS in folder 'Stock'
# Downloaded and saved data for ARWR in folder 'Stock'
# Downloaded and saved data for ARTY in folder 'ETF'
# Downloaded and saved data for ASAN in folder 'Stock'
# Downloaded and saved data for ASA in folder 'Stock'
# No data available for ARTW
# No data available for ASB
# Downloaded and saved data for ASC in folder 'Stock'
# Downloaded and saved data for ASBP in folder 'Stock'
# Downloaded and saved data for ASBA in folder 'Stock'
# Downloaded and saved data for ASB$F in folder 'Unknown'
# Downloaded and saved data for ARW in folder 'Stock'
# Downloaded and saved data for ARVN in folder 'Stock'
# Downloaded and saved data for ASB$E in folder 'Unknown'
# Downloaded and saved data for ASBPW in folder 'Stock'
# Downloaded and saved data for ASGN in folder 'Stock'
# Downloaded and saved data for ASG in folder 'Stock'
# Downloaded and saved data for ASEA in folder 'ETF'
# Downloaded and saved data for ASH in folder 'Stock'
# Downloaded and saved data for ASET in folder 'ETF'
# Downloaded and saved data for ASGI in folder 'Stock'
# Downloaded and saved data for ASLE in folder 'Stock'
# Downloaded and saved data for ASM in folder 'Stock'
# Downloaded and saved data for ASIA in folder 'ETF'
# Downloaded and saved data for ASMF in folder 'ETF'
# Downloaded and saved data for ASMB in folder 'Stock'
# Downloaded and saved data for ASIX in folder 'Stock'
# Downloaded and saved data for ASMG in folder 'Stock'
# Downloaded and saved data for ASHR in folder 'ETF'
# Downloaded and saved data for ASPCR in folder 'Stock'
# Downloaded and saved data for ASO in folder 'Stock'
# Downloaded and saved data for ASPC in folder 'Stock'
# Downloaded and saved data for ASML in folder 'Stock'
# Downloaded and saved data for ASNS in folder 'Stock'
# Downloaded and saved data for ASND in folder 'Stock'
# Downloaded and saved data for ASPS in folder 'Stock'
# Downloaded and saved data for ASMH in folder 'ETF'
# Downloaded and saved data for ASPN in folder 'Stock'
# Downloaded and saved data for ASPCU in folder 'Stock'
# Downloaded and saved data for ASRV in folder 'Stock'
# Downloaded and saved data for ASTC in folder 'Stock'
# Downloaded and saved data for ASR in folder 'Stock'
# Downloaded and saved data for ASST in folder 'Stock'
# Downloaded and saved data for ASTE in folder 'Stock'
# Downloaded and saved data for ASRT in folder 'Stock'
# Downloaded and saved data for ASTH in folder 'Stock'
# Downloaded and saved data for ASTS in folder 'Stock'
# Downloaded and saved data for ASTLW in folder 'Stock'
# Downloaded and saved data for ASUR in folder 'Stock'
# No data available for ASPI
# Downloaded and saved data for ASTL in folder 'Stock'
# Downloaded and saved data for ASTI in folder 'Stock'
# Downloaded and saved data for ASHS in folder 'ETF'
# Downloaded and saved data for ATCH in folder 'Stock'
# Downloaded and saved data for ATCO$H in folder 'Unknown'
# Downloaded and saved data for ATCOL in folder 'Stock'
# Downloaded and saved data for ASX in folder 'Stock'
# Downloaded and saved data for ASYS in folder 'Stock'
# Downloaded and saved data for ATCO$D in folder 'Unknown'
# Downloaded and saved data for ATAI in folder 'Stock'
# Downloaded and saved data for ATAT in folder 'Stock'
# Downloaded and saved data for ATEX in folder 'Stock'
# Downloaded and saved data for ATEC in folder 'Stock'
# Downloaded and saved data for ATGE in folder 'Stock'
# Downloaded and saved data for ATEN in folder 'Stock'
# Downloaded and saved data for ATFV in folder 'ETF'
# Downloaded and saved data for ATH$A in folder 'Unknown'
# Downloaded and saved data for ATGL in folder 'Stock'
# Downloaded and saved data for ATER in folder 'Stock'
# No data available for ATH$B
# No data available for ATH$C
# No data available for ATHS
# No data available for ATHA
# No data available for ATH$D
# No data available for ATH$E
# No data available for ATHM
# Downloaded and saved data for ATLC in folder 'Stock'
# Downloaded and saved data for ATLCP in folder 'Stock'
# Downloaded and saved data for ATLCZ in folder 'Stock'
# Downloaded and saved data for ATLCL in folder 'Stock'
# Downloaded and saved data for ATLN in folder 'Stock'
# Downloaded and saved data for ATHE in folder 'Stock'
# Downloaded and saved data for ATLX in folder 'Stock'
# Downloaded and saved data for ATIIU in folder 'Stock'
# Downloaded and saved data for ATKR in folder 'Stock'
# Downloaded and saved data for ATLO in folder 'Stock'
# Downloaded and saved data for ATMC in folder 'Stock'
# Downloaded and saved data for ATI in folder 'Stock'
# Downloaded and saved data for ATMCW in folder 'Stock'
# Downloaded and saved data for ATMU in folder 'Stock'
# Downloaded and saved data for ATMCU in folder 'Stock'
# Downloaded and saved data for ATMP in folder 'ETF'
# Downloaded and saved data for ATMCR in folder 'Stock'
# Downloaded and saved data for ATO in folder 'Stock'
# Downloaded and saved data for ATNF in folder 'Stock'
# Downloaded and saved data for ATOM in folder 'Stock'
# Downloaded and saved data for ATNI in folder 'Stock'
# Downloaded and saved data for ATMVU in folder 'Stock'
# Downloaded and saved data for ATNM in folder 'Stock'
# Downloaded and saved data for ATMVR in folder 'Stock'
# Downloaded and saved data for ATMV in folder 'Stock'
# Downloaded and saved data for ATNFW in folder 'Stock'
# Downloaded and saved data for ATR in folder 'Stock'
# Downloaded and saved data for ATRA in folder 'Stock'
# Downloaded and saved data for ATXG in folder 'Stock'
# Downloaded and saved data for ATUS in folder 'Stock'
# Downloaded and saved data for ATRC in folder 'Stock'
# Downloaded and saved data for ATXS in folder 'Stock'
# Downloaded and saved data for ATS in folder 'Stock'
# Downloaded and saved data for ATSG in folder 'Stock'
# Downloaded and saved data for ATPC in folder 'Stock'
# Downloaded and saved data for ATOS in folder 'Stock'
# Downloaded and saved data for AUGM in folder 'ETF'
# Downloaded and saved data for AU in folder 'Stock'
# Downloaded and saved data for AUDC in folder 'Stock'
# Downloaded and saved data for AUB$A in folder 'Unknown'
# Downloaded and saved data for ATYR in folder 'Stock'
# Downloaded and saved data for AUBN in folder 'Stock'
# Downloaded and saved data for ATRO in folder 'Stock'
# Downloaded and saved data for AUB in folder 'Stock'
# Downloaded and saved data for AUMI in folder 'ETF'
# Downloaded and saved data for AUGZ in folder 'ETF'
# Downloaded and saved data for AUGT in folder 'ETF'
# Downloaded and saved data for AUID in folder 'Stock'
# Downloaded and saved data for AUGU in folder 'ETF'
# Downloaded and saved data for AUGP in folder 'ETF'
# Downloaded and saved data for AUGW in folder 'ETF'
# Downloaded and saved data for AUNA in folder 'Stock'
# No data available for AUR
# No data available for AUSF
# No data available for AUPH
# No data available for AUST
# No data available for AUUD
# No data available for AURA
# No data available for AUTL
# No data available for AUROW
# Downloaded and saved data for AVBP in folder 'Stock'
# Downloaded and saved data for AVD in folder 'Stock'
# Downloaded and saved data for AVB in folder 'Stock'
# Downloaded and saved data for AUUDW in folder 'Stock'
# Downloaded and saved data for AVA in folder 'Stock'
# Downloaded and saved data for AVDV in folder 'ETF'
# Downloaded and saved data for AVDL in folder 'Stock'
# Downloaded and saved data for AVAV in folder 'Stock'
# Downloaded and saved data for AVAL in folder 'Stock'
# Downloaded and saved data for AVDE in folder 'ETF'
# Downloaded and saved data for AVAH in folder 'Stock'
# Downloaded and saved data for AVDS in folder 'ETF'
# Downloaded and saved data for AVDX in folder 'Stock'
# Downloaded and saved data for AVEM in folder 'ETF'
# Downloaded and saved data for AVGE in folder 'ETF'
# Downloaded and saved data for AVEE in folder 'ETF'
# Downloaded and saved data for AVGV in folder 'ETF'
# Downloaded and saved data for AVGO in folder 'Stock'
# Downloaded and saved data for AVGX in folder 'ETF'
# Downloaded and saved data for AVES in folder 'ETF'
# Downloaded and saved data for AVIG in folder 'ETF'
# Downloaded and saved data for AVK in folder 'Stock'
# Downloaded and saved data for AVL in folder 'Stock'
# Downloaded and saved data for AVIE in folder 'ETF'
# Downloaded and saved data for AVIV in folder 'ETF'
# Downloaded and saved data for AVIR in folder 'Stock'
# Downloaded and saved data for AVLV in folder 'ETF'
# Downloaded and saved data for AVLC in folder 'ETF'
# Downloaded and saved data for AVMV in folder 'ETF'
# Downloaded and saved data for AVMU in folder 'ETF'
# Downloaded and saved data for AVNV in folder 'ETF'
# Downloaded and saved data for AVNT in folder 'Stock'
# Downloaded and saved data for AVMA in folder 'ETF'
# Downloaded and saved data for AVNS in folder 'Stock'
# Downloaded and saved data for AVNM in folder 'ETF'
# Downloaded and saved data for AVMC in folder 'ETF'
# No data available for AVR
# No data available for AVNW
# No data available for AVSC
# No data available for AVSD
# No data available for AVSE
# No data available for AVS
# No data available for AVPTW
# No data available for AVSF
# No data available for AVRE
# No data available for AVO
# Downloaded and saved data for AVTE in folder 'Stock'
# Downloaded and saved data for AVSU in folder 'ETF'
# Downloaded and saved data for AVTR in folder 'Stock'
# Downloaded and saved data for AVTX in folder 'Stock'
# Downloaded and saved data for AVT in folder 'Stock'
# Downloaded and saved data for AVPT in folder 'Stock'
# Downloaded and saved data for AVUS in folder 'ETF'
# Downloaded and saved data for AVUV in folder 'ETF'
# Downloaded and saved data for AWF in folder 'Stock'
# Downloaded and saved data for AVXL in folder 'Stock'
# No data available for AWI
# Downloaded and saved data for AWEG in folder 'ETF'
# Downloaded and saved data for AVY in folder 'Stock'
# Downloaded and saved data for AVXC in folder 'ETF'
# Downloaded and saved data for AWAY in folder 'ETF'
# Downloaded and saved data for AWH in folder 'Stock'
# Downloaded and saved data for AXDX in folder 'Stock'
# Downloaded and saved data for AWR in folder 'Stock'
# Downloaded and saved data for AWP in folder 'Stock'
# Downloaded and saved data for AXON in folder 'Stock'
# Downloaded and saved data for AXIL in folder 'Stock'
# Downloaded and saved data for AWX in folder 'Stock'
# Downloaded and saved data for AX in folder 'Stock'
# Downloaded and saved data for AXS in folder 'Stock'
# Downloaded and saved data for AXR in folder 'Stock'
# Downloaded and saved data for AXP in folder 'Stock'
# Downloaded and saved data for AXS$E in folder 'Unknown'
# Downloaded and saved data for AXL in folder 'Stock'
# Downloaded and saved data for AWK in folder 'Stock'
# Downloaded and saved data for AXGN in folder 'Stock'
# Downloaded and saved data for AWRE in folder 'Stock'
# Downloaded and saved data for AXTA in folder 'Stock'
# Downloaded and saved data for AZEK in folder 'Stock'
# Downloaded and saved data for AXTI in folder 'Stock'
# Downloaded and saved data for AZ in folder 'Stock'
# Downloaded and saved data for AYTU in folder 'Stock'
# Downloaded and saved data for AYRO in folder 'Stock'
# Downloaded and saved data for AYI in folder 'Stock'
# Downloaded and saved data for AXSM in folder 'Stock'
# Downloaded and saved data for AZTD in folder 'ETF'
# Downloaded and saved data for AZNH in folder 'ETF'
# Downloaded and saved data for AZN in folder 'Stock'
# Downloaded and saved data for AZUL in folder 'Stock'
# Downloaded and saved data for AZI in folder 'Stock'
# Downloaded and saved data for BA in folder 'Stock'
# Downloaded and saved data for AZZ in folder 'Stock'
# Downloaded and saved data for BAB in folder 'ETF'
# Downloaded and saved data for AZTA in folder 'Stock'
# Downloaded and saved data for BABO in folder 'ETF'
# Downloaded and saved data for BABA in folder 'Stock'
# Downloaded and saved data for AZO in folder 'Stock'
# Downloaded and saved data for BA$A in folder 'Unknown'
# Downloaded and saved data for BABX in folder 'ETF'
# Downloaded and saved data for AZTR in folder 'Stock'
# Downloaded and saved data for BAC$L in folder 'Unknown'
# Downloaded and saved data for BAC$N in folder 'Unknown'
# Downloaded and saved data for BAC in folder 'Stock'
# Downloaded and saved data for BAC$M in folder 'Unknown'
# Downloaded and saved data for BAC$K in folder 'Unknown'
# Downloaded and saved data for BAC$B in folder 'Unknown'
# Downloaded and saved data for BAC$E in folder 'Unknown'
# Downloaded and saved data for BAC$O in folder 'Unknown'
# No data available for BAC$Q
# No data available for BACQU
# No data available for BAC$P
# No data available for BAER
# No data available for BAC$S
# No data available for BACQ
# No data available for BACK
# Downloaded and saved data for BAH in folder 'Stock'
# Downloaded and saved data for BAK in folder 'Stock'
# Downloaded and saved data for BAFE in folder 'Stock'
# Downloaded and saved data for BACQR in folder 'Stock'
# Downloaded and saved data for BAI in folder 'ETF'
# Downloaded and saved data for BAFN in folder 'Stock'
# Downloaded and saved data for BALI in folder 'ETF'
# Downloaded and saved data for BAMA in folder 'ETF'
# Downloaded and saved data for BALT in folder 'ETF'
# Downloaded and saved data for BAERW in folder 'Stock'
# Downloaded and saved data for BALL in folder 'Stock'
# Downloaded and saved data for BAMB in folder 'ETF'
# Downloaded and saved data for BAMD in folder 'ETF'
# Downloaded and saved data for BAM in folder 'Stock'
# Downloaded and saved data for BALY in folder 'Stock'
# No data available for BAMG
# Downloaded and saved data for BAMU in folder 'ETF'
# Downloaded and saved data for BAMO in folder 'ETF'
# Downloaded and saved data for BAMV in folder 'ETF'
# Downloaded and saved data for BANL in folder 'Stock'
# Downloaded and saved data for BANC$F in folder 'Unknown'
# Downloaded and saved data for BANC in folder 'Stock'
# Downloaded and saved data for BAMY in folder 'ETF'
# Downloaded and saved data for BANR in folder 'Stock'
# Downloaded and saved data for BANX in folder 'Stock'
# Downloaded and saved data for BAND in folder 'Stock'
# Downloaded and saved data for BANF in folder 'Stock'
# ...
# Downloaded and saved data for WWD in folder 'Stock'
# Downloaded and saved data for WWW in folder 'Stock'
# Downloaded and saved data for X in folder 'Stock'
# Downloaded and saved data for WYY in folder 'Stock'
# Downloaded and saved data for WYNN in folder 'Stock'
# Downloaded and saved data for WYHG in folder 'Stock'
# Downloaded and saved data for WWJD in folder 'ETF'
# Downloaded and saved data for WXET in folder 'ETF'
# Downloaded and saved data for WWR in folder 'Stock'
# Downloaded and saved data for WY in folder 'Stock'
# Downloaded and saved data for XAUG in folder 'ETF'
# Downloaded and saved data for XAGEW in folder 'Stock'
# Downloaded and saved data for XAR in folder 'ETF'
# Downloaded and saved data for XAPR in folder 'ETF'
# Downloaded and saved data for XAGE in folder 'Stock'
# Downloaded and saved data for XAIX in folder 'Stock'
# Downloaded and saved data for XAIR in folder 'Stock'
# Downloaded and saved data for XBB in folder 'ETF'
# Downloaded and saved data for XBIL in folder 'ETF'
# Downloaded and saved data for XBJA in folder 'ETF'
# Downloaded and saved data for XBIT in folder 'Stock'
# Downloaded and saved data for XBIO in folder 'Stock'
# Downloaded and saved data for XB in folder 'ETF'
# Downloaded and saved data for XBI in folder 'ETF'
# Downloaded and saved data for XBAP in folder 'ETF'
# Downloaded and saved data for XCEM in folder 'ETF'
# Downloaded and saved data for XCCC in folder 'ETF'
# Downloaded and saved data for XCH in folder 'Stock'
# Downloaded and saved data for XBOC in folder 'ETF'
# Downloaded and saved data for XBJL in folder 'ETF'
# Downloaded and saved data for XBP in folder 'Stock'
# Downloaded and saved data for XBPEW in folder 'Stock'
# Downloaded and saved data for XDAP in folder 'ETF'
# Downloaded and saved data for XC in folder 'ETF'
# Downloaded and saved data for XCLR in folder 'ETF'
# Downloaded and saved data for XCUR in folder 'Stock'
# Downloaded and saved data for XDAT in folder 'ETF'
# Downloaded and saved data for XCNY in folder 'Stock'
# Downloaded and saved data for XCOR in folder 'ETF'
# Downloaded and saved data for XEL in folder 'Stock'
# Downloaded and saved data for XDOC in folder 'ETF'
# Downloaded and saved data for XDQQ in folder 'ETF'
# Downloaded and saved data for XELB in folder 'Stock'
# Downloaded and saved data for XDEC in folder 'ETF'
# Downloaded and saved data for XDJL in folder 'ETF'
# Downloaded and saved data for XDTE in folder 'ETF'
# Downloaded and saved data for XDSQ in folder 'ETF'
# No data available for XFIX
# No data available for XENE
# No data available for XERS
# No data available for XFLT
# No data available for XEMD
# No data available for XFEB
# No data available for XES
# No data available for XFIV
# Downloaded and saved data for XGN in folder 'Stock'
# Downloaded and saved data for XHE in folder 'ETF'
# Downloaded and saved data for XHB in folder 'ETF'
# Downloaded and saved data for XHG in folder 'Stock'
# Downloaded and saved data for XFLT$A in folder 'Unknown'
# No data available for XHLD
# No data available for XHR
# No data available for XHLF
# Downloaded and saved data for XFOR in folder 'Stock'
# Downloaded and saved data for XFLX in folder 'ETF'
# Downloaded and saved data for XHS in folder 'ETF'
# Downloaded and saved data for XHYI in folder 'ETF'
# Downloaded and saved data for XHYT in folder 'ETF'
# Downloaded and saved data for XHYE in folder 'ETF'
# Downloaded and saved data for XIDE in folder 'ETF'
# Downloaded and saved data for XHYC in folder 'ETF'
# Downloaded and saved data for XIDV in folder 'ETF'
# Downloaded and saved data for XHYD in folder 'ETF'
# Downloaded and saved data for XHYH in folder 'ETF'
# Downloaded and saved data for XIJN in folder 'ETF'
# Downloaded and saved data for XHYF in folder 'ETF'
# Downloaded and saved data for XITK in folder 'ETF'
# Downloaded and saved data for XISE in folder 'ETF'
# Downloaded and saved data for XIN in folder 'Stock'
# Downloaded and saved data for XIFR in folder 'Stock'
# Downloaded and saved data for XIMR in folder 'ETF'
# Downloaded and saved data for XJH in folder 'ETF'
# Downloaded and saved data for XJR in folder 'ETF'
# Downloaded and saved data for XJAN in folder 'ETF'
# Downloaded and saved data for XLG in folder 'ETF'
# No data available for XLC
# Downloaded and saved data for XLF in folder 'ETF'
# Downloaded and saved data for XLB in folder 'ETF'
# Downloaded and saved data for XLE in folder 'ETF'
# Downloaded and saved data for XJUN in folder 'ETF'
# Downloaded and saved data for XLI in folder 'ETF'
# Downloaded and saved data for XJUL in folder 'ETF'
# Downloaded and saved data for XLY in folder 'ETF'
# Downloaded and saved data for XLP in folder 'ETF'
# Downloaded and saved data for XLO in folder 'Stock'
# Downloaded and saved data for XLSR in folder 'ETF'
# Downloaded and saved data for XLK in folder 'ETF'
# Downloaded and saved data for XLRE in folder 'ETF'
# Downloaded and saved data for XLV in folder 'ETF'
# Downloaded and saved data for XMHQ in folder 'ETF'
# No data available for XMAG
# No data available for XMAY
# No data available for XME
# Downloaded and saved data for XMPT in folder 'ETF'
# Downloaded and saved data for XNAV in folder 'ETF'
# Downloaded and saved data for XMVM in folder 'ETF'
# Downloaded and saved data for XMMO in folder 'ETF'
# Downloaded and saved data for XMAR in folder 'ETF'
# Downloaded and saved data for XLU in folder 'ETF'
# Downloaded and saved data for XNOV in folder 'ETF'
# Downloaded and saved data for XNTK in folder 'ETF'
# Downloaded and saved data for XNCR in folder 'Stock'
# Downloaded and saved data for XMTR in folder 'Stock'
# Downloaded and saved data for XOCT in folder 'ETF'
# Downloaded and saved data for XOM in folder 'Stock'
# Downloaded and saved data for XNET in folder 'Stock'
# Downloaded and saved data for XOP in folder 'ETF'
# Downloaded and saved data for XONE in folder 'ETF'
# Downloaded and saved data for XOMO in folder 'ETF'
# Downloaded and saved data for XOS in folder 'Stock'
# Downloaded and saved data for XOMAP in folder 'Stock'
# Downloaded and saved data for XOMAO in folder 'Stock'
# Downloaded and saved data for XOMA in folder 'Stock'
# Downloaded and saved data for XMLV in folder 'ETF'
# Downloaded and saved data for XP in folder 'Stock'
# Downloaded and saved data for XPER in folder 'Stock'
# Downloaded and saved data for XOSWW in folder 'Stock'
# Downloaded and saved data for XPAY in folder 'ETF'
# Downloaded and saved data for XPEV in folder 'Stock'
# Downloaded and saved data for XOVR in folder 'Stock'
# Downloaded and saved data for XPEL in folder 'Stock'
# Downloaded and saved data for XPL in folder 'Stock'
# Downloaded and saved data for XPND in folder 'ETF'
# Downloaded and saved data for XPP in folder 'ETF'
# Downloaded and saved data for XPOF in folder 'Stock'
# Downloaded and saved data for XPRO in folder 'Stock'
# Downloaded and saved data for XPH in folder 'ETF'
# Downloaded and saved data for XPO in folder 'Stock'
# Downloaded and saved data for XPON in folder 'Stock'
# Downloaded and saved data for XRT in folder 'ETF'
# Downloaded and saved data for XRAY in folder 'Stock'
# Downloaded and saved data for XRLX in folder 'ETF'
# Downloaded and saved data for XRMI in folder 'ETF'
# Downloaded and saved data for XSD in folder 'ETF'
# Downloaded and saved data for XRTX in folder 'Stock'
# Downloaded and saved data for XRX in folder 'Stock'
# Downloaded and saved data for XRLV in folder 'ETF'
# Downloaded and saved data for XSEP in folder 'ETF'
# Downloaded and saved data for XSHD in folder 'ETF'
# Downloaded and saved data for XSVM in folder 'ETF'
# Downloaded and saved data for XSW in folder 'ETF'
# Downloaded and saved data for XTAP in folder 'ETF'
# Downloaded and saved data for XSVN in folder 'ETF'
# Downloaded and saved data for XTJA in folder 'ETF'
# Downloaded and saved data for XTIA in folder 'Stock'
# Downloaded and saved data for XSLV in folder 'ETF'
# Downloaded and saved data for XT in folder 'ETF'
# Downloaded and saved data for XSHQ in folder 'ETF'
# Downloaded and saved data for XSOE in folder 'ETF'
# Downloaded and saved data for XTEN in folder 'ETF'
# Downloaded and saved data for XSMO in folder 'ETF'
# Downloaded and saved data for XTKG in folder 'Stock'
# Downloaded and saved data for XTLB in folder 'Stock'
# Downloaded and saved data for XTNT in folder 'Stock'
# Downloaded and saved data for XTOC in folder 'ETF'
# Downloaded and saved data for XTN in folder 'ETF'
# Downloaded and saved data for XTR in folder 'ETF'
# Downloaded and saved data for XTL in folder 'ETF'
# Downloaded and saved data for XTJL in folder 'ETF'
# Downloaded and saved data for XTWY in folder 'ETF'
# Downloaded and saved data for XTRE in folder 'ETF'
# Downloaded and saved data for XUSP in folder 'ETF'
# Downloaded and saved data for XUDV in folder 'ETF'
# Downloaded and saved data for XVV in folder 'ETF'
# Downloaded and saved data for XWEL in folder 'Stock'
# Downloaded and saved data for XTWO in folder 'ETF'
# Downloaded and saved data for XVOL in folder 'ETF'
# Downloaded and saved data for XYLD in folder 'ETF'
# Downloaded and saved data for XXII in folder 'Stock'
# Downloaded and saved data for XYL in folder 'Stock'
# Downloaded and saved data for XYLO in folder 'Stock'
# Downloaded and saved data for XYLG in folder 'ETF'
# Downloaded and saved data for XYZ in folder 'Stock'
# Downloaded and saved data for XXCH in folder 'ETF'
# Downloaded and saved data for XYF in folder 'Stock'
# No data available for YBTC
# Downloaded and saved data for YAAS in folder 'Stock'
# Downloaded and saved data for YCBD$A in folder 'Unknown'
# Downloaded and saved data for YCL in folder 'ETF'
# Downloaded and saved data for YALA in folder 'Stock'
# Downloaded and saved data for YBIT in folder 'ETF'
# Downloaded and saved data for YCBD in folder 'Stock'
# Downloaded and saved data for YANG in folder 'ETF'
# Downloaded and saved data for YALL in folder 'ETF'
# Downloaded and saved data for YCS in folder 'ETF'
# Downloaded and saved data for YETI in folder 'Stock'
# Downloaded and saved data for YETH in folder 'ETF'
# Downloaded and saved data for YEXT in folder 'Stock'
# Downloaded and saved data for YFFI in folder 'ETF'
# Downloaded and saved data for YEAR in folder 'ETF'
# Downloaded and saved data for YELP in folder 'Stock'
# Downloaded and saved data for YDEC in folder 'ETF'
# No data available for YGLD
# No data available for YGMZ
# Downloaded and saved data for YHC in folder 'Stock'
# Downloaded and saved data for YIBO in folder 'Stock'
# Downloaded and saved data for YHNA in folder 'Stock'
# Downloaded and saved data for YI in folder 'Stock'
# Downloaded and saved data for YHNAR in folder 'Stock'
# Downloaded and saved data for YHNAU in folder 'Stock'
# Downloaded and saved data for YHGJ in folder 'Stock'
# Downloaded and saved data for YFYA in folder 'ETF'
# Downloaded and saved data for YMAB in folder 'Stock'
# Downloaded and saved data for YLDE in folder 'ETF'
# Downloaded and saved data for YJ in folder 'Stock'
# Downloaded and saved data for YINN in folder 'ETF'
# Downloaded and saved data for YLD in folder 'ETF'
# Downloaded and saved data for YMAG in folder 'ETF'
# Downloaded and saved data for YMAR in folder 'ETF'
# No data available for YOSH
# No data available for YOLO
# No data available for YORW
# No data available for YMAX
# No data available for YJUN
# No data available for YOKE
# No data available for YOTA
# No data available for YMM
# No data available for YPF
# Downloaded and saved data for YQQQ in folder 'Stock'
# Downloaded and saved data for YOTAU in folder 'Stock'
# Downloaded and saved data for YOTAR in folder 'Stock'
# No data available for YQ
# Downloaded and saved data for YSEP in folder 'ETF'
# Downloaded and saved data for YRD in folder 'Stock'
# Downloaded and saved data for YSG in folder 'Stock'
# Downloaded and saved data for YXI in folder 'ETF'
# Downloaded and saved data for YOU in folder 'Stock'
# Downloaded and saved data for YTRA in folder 'Stock'
# Downloaded and saved data for YUM in folder 'Stock'
# Downloaded and saved data for YSXT in folder 'Stock'
# Downloaded and saved data for YOTAW in folder 'Stock'
# Downloaded and saved data for YUMC in folder 'Stock'
# Downloaded and saved data for YSPY in folder 'Stock'
# No data available for YXT
# Downloaded and saved data for YYY in folder 'ETF'
# No data available for YYAI
# Downloaded and saved data for ZALT in folder 'ETF'
# Downloaded and saved data for Z in folder 'Stock'
# Downloaded and saved data for YY in folder 'Stock'
# Downloaded and saved data for ZAUG in folder 'ETF'
# Downloaded and saved data for ZAPP in folder 'Stock'
# Downloaded and saved data for ZAPPW in folder 'Stock'
# Downloaded and saved data for ZBRA in folder 'Stock'
# Downloaded and saved data for ZBAI in folder 'Stock'
# Downloaded and saved data for YYGH in folder 'Stock'
# Downloaded and saved data for ZBAO in folder 'Stock'
# Downloaded and saved data for ZBIO in folder 'Stock'
# Downloaded and saved data for ZAP in folder 'Stock'
# Downloaded and saved data for ZCMD in folder 'Stock'
# Downloaded and saved data for ZCAR in folder 'Stock'
# Downloaded and saved data for ZCARW in folder 'Stock'
# Downloaded and saved data for ZBH in folder 'Stock'
# Downloaded and saved data for ZD in folder 'Stock'
# Downloaded and saved data for ZENV in folder 'Stock'
# Downloaded and saved data for ZEO in folder 'Stock'
# No data available for ZECP
# No data available for ZDEK
# Downloaded and saved data for ZEPP in folder 'Stock'
# Downloaded and saved data for ZDGE in folder 'Stock'
# Downloaded and saved data for ZENA in folder 'Stock'
# Downloaded and saved data for ZEOWW in folder 'Stock'
# Downloaded and saved data for ZI in folder 'Stock'
# Downloaded and saved data for ZHDG in folder 'ETF'
# Downloaded and saved data for ZEUS in folder 'Stock'
# Downloaded and saved data for ZH in folder 'Stock'
# Downloaded and saved data for ZETA in folder 'Stock'
# Downloaded and saved data for ZFEB in folder 'ETF'
# Downloaded and saved data for ZG in folder 'Stock'
# Downloaded and saved data for ZGN in folder 'Stock'
# Downloaded and saved data for ZION in folder 'Stock'
# No data available for ZIPP
# Downloaded and saved data for ZIG in folder 'ETF'
# Downloaded and saved data for ZIONP in folder 'Stock'
# Downloaded and saved data for ZIM in folder 'Stock'
# Downloaded and saved data for ZJAN in folder 'ETF'
# Downloaded and saved data for ZIMV in folder 'Stock'
# Downloaded and saved data for ZIP in folder 'Stock'
# Downloaded and saved data for ZM in folder 'Stock'
# Downloaded and saved data for ZLAB in folder 'Stock'
# No data available for ZJYL
# No data available for ZKIN
# No data available for ZJUL
# No data available for ZJK
# No data available for ZKH
# No data available for ZK
# Downloaded and saved data for ZONE in folder 'Stock'
# Downloaded and saved data for ZOOZW in folder 'Stock'
# Downloaded and saved data for ZROZ in folder 'ETF'
# Downloaded and saved data for ZNOV in folder 'ETF'
# Downloaded and saved data for ZOOZ in folder 'Stock'
# Downloaded and saved data for ZMAR in folder 'ETF'
# Downloaded and saved data for ZSL in folder 'ETF'
# Downloaded and saved data for ZSB in folder 'ETF'
# Downloaded and saved data for ZSPC in folder 'Stock'
# Downloaded and saved data for ZSEP in folder 'ETF'
# Downloaded and saved data for ZS in folder 'Stock'
# Downloaded and saved data for ZSC in folder 'ETF'
# Downloaded and saved data for ZTEK in folder 'Stock'
# Downloaded and saved data for ZTO in folder 'Stock'
# Downloaded and saved data for ZTR in folder 'Stock'
# Downloaded and saved data for ZOCT in folder 'ETF'
# Downloaded and saved data for ZTEN in folder 'ETF'
# Downloaded and saved data for ZTAX in folder 'ETF'
# Downloaded and saved data for ZNTL in folder 'Stock'
# Downloaded and saved data for ZVIA in folder 'Stock'
# Downloaded and saved data for ZURA in folder 'Stock'
# Downloaded and saved data for ZUMZ in folder 'Stock'
# Downloaded and saved data for ZTRE in folder 'ETF'
# Downloaded and saved data for ZVOL in folder 'ETF'
# Downloaded and saved data for ZTWO in folder 'ETF'
# Downloaded and saved data for ZTS in folder 'Stock'
# Downloaded and saved data for ZVRA in folder 'Stock'
# Downloaded and saved data for ZYBT in folder 'Stock'
# Downloaded and saved data for ZWS in folder 'Stock'
# Downloaded and saved data for ZYME in folder 'Stock'
# Downloaded and saved data for ZYXI in folder 'Stock'
# Downloaded and saved data for ZVSA in folder 'Stock'
# Downloaded and saved data for ZZZ in folder 'ETF'
